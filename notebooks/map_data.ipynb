# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import networkx as nx

# %%
regionListNew = ['San Antonio TX', 'Miami FL', 'Richland WA', 'Naples FL',
       'Wilkes-Barre PA', 'Danville PA', 'Portland OR', 'Seattle WA',
       'Wichita KS', 'Worcester MA', 'Pittsburgh PA', 'Boston MA',
       'Albuquerque NM', 'Providence RI', 'Las Vegas NV', 'San Francisco CA',
       'Raleigh NC', 'Detroit MI', 'Burlington VT', 'Charleston SC',
       'Jacksonville FL', 'Ridgewood NJ', 'Omaha NE', 'Newberg OR',
       'Birmingham AL', 'Decatur GA', 'Melbourne FL', 'Cocoa Beach FL',
       'Tavernier FL', 'Albany NY', 'Santa Monica CA', 'Euclid OH',
       'Cleveland OH', 'Houston TX', 'Dallas TX', 'Southfield MI',
       'Madison WI', 'Tulsa OK', 'Newport RI', 'Reading PA', 'Annapolis MD',
       'Morgantown WV', 'Manhattan NY', 'San Diego CA', 'Greensboro NC',
       'Monroe NC', 'Fernandina Beach FL', 'Chicago IL', 'Kings Mountain NC',
       'South Miami FL', 'Sacramento CA', 'St. Louis MO', 'Boulder City NV',
       'Mayfield Heights OH', 'Durham NC', 'Kennewick WA', 'Grand Rapids MI',
       'Bangor ME', 'Charlotte NC', 'Coral Gables FL', 'Shelby NC',
       'Wilmington DE', 'Marlborough MA', 'Bethesda MD', 'Mount Holly NJ',
       'Maryville IL', 'Philadelphia PA', 'Camden NJ', 'Takoma Park MD',
       'Rockville MD', 'Minneapolis MN', 'Allentown PA', 'Bethlehem PA',
       'Washington DC', 'Sapulpa OK', 'Memphis TN', 'Bartlesville OK',
       'Coronado CA', 'La Jolla CA', 'Grand Forks ND', 'Encinitas CA',
       'Tacoma WA', 'Clinton MA', 'Conroe TX', 'Mesa AZ', 'Phoenix AZ',
       'Charlottesville VA', 'Chula Vista CA', 'Evergreen AL',
       'Long Beach CA', 'Oklahoma City OK', 'West Chester PA', 'Alabaster AL',
       'Pasco WA', 'Fountain Valley CA', 'Brownsville TN', 'Brockton MA',
       'Vinita OK', 'Burlington MA', 'Shreveport LA', 'Tillamook/Wheeler OR',
       'Ann Arbor MI', 'New Orleans LA', 'Baton Rouge LA', 'Fairfax VA',
       'Hawthorne NV', 'Honolulu HI', 'Morganton NC', 'Valdese NC',
       'White Plains NY', 'Port Chester NY', 'Page AZ', 'Syracuse NY',
       'Pocahontas AR', 'Atlanta GA', 'Austell GA' , 'Battle Mountain NV' , 'Bellingham WA' ,
        'Bemidji MN' , 'Biloxi MS', 'Buffalo OK' , 'Bullhead City AZ' , 'Carson City NV' , 'Cartersville GA' ,
        'Centre AL' , 'Columbus GA' , 'Cottage Grove OR' , 'Cullman AL' , 'Denver CO' , 'Dublin GA' , 'El Paso TX' ,
        'Enid OK' , 'Eugene OR' , 'Fairview OK' , 'Fallon NV' , 'Federal Way WA' , 'Flemingsburg KY' , 'Florence OR' ,
        'Fort Lauderdale FL' , 'Fort Payne AL' , 'Fort Pierce FL' , 'Fort Wayne IN' , 'Gainesville GA' , 'Galveston TX' , 'Hackensack NJ' , 'Harrisburg PA' ,
        'Henderson NV' , 'Indianapolis IN' , 'Iowa City IA' , 'Jackson MS' , 'Jasper AL' , 'Kansas City MO' , 'Ketchikan AK' ,
        'Knoxville TN' , 'La Jolla CA' , 'Lakeland FL' , 'LaMesa CA' , 'Las Vegas NV' , 'Lexington KY' , 'Little Rock AR' ,
        'Los Alamitos CA' , 'Los Angeles CA' , 'Louisville KY' , 'Lubbock TX' , 'Miami Beach FL' , 'Milford MI' , 'Milwaukee WI' ,
        'Mobile AL' , 'Moulton AL' , 'Mount Clemens MI' , 'Munster IN' , 'Napoleon OH' , 'Newark NJ' , 'Newnan GA' , 'Okeechobee FL' , 'Okeene OK' , 'Orlando FL' , 
        'Pembroke Pines FL' , 'Plantation FL' , 'Port St. Lucie FL' , 'Reno NV' , 'Rochester NY' , 'Salem VA' , 'Salt Lake City UT' , 'San Jose CA' , 
        'Seaside OR' , 'Seiling OK' , 'Sioux Falls SD' , 'Snellville GA' , 'Sodus NY' , 'Spartanburg SC' , 'Springfield IL' , 'Stanford CA' , 'Sylacauga AL' , 
        'Talladega AL' , 'Toledo OH' , 'Torrance CA' , 'Truckee CA' , 'Tucson AZ' , 'Urbana IL' , 'Winder GA' , 'Winnemucca NV']

# %%
geo
# Out:
#               Region        lat        long
# 0     San Antonio TX  29.424600  -98.495141
# 1           Miami FL  25.774173  -80.193620
# 2        Richland WA  46.280430 -119.275205
# 3          Naples FL  26.142198  -81.794294
# 4    Wilkes-Barre PA  41.246482  -75.881732
# ..               ...        ...         ...
# 197       Truckee CA  39.327962 -120.183253
# 198        Tucson AZ  32.222876 -110.974848
# 199        Urbana IL  40.111717  -88.207301
# 200        Winder GA  54.541145   -3.483117
# 201    Winnemucca NV  40.972428 -117.734818
#
# [202 rows x 3 columns]

# %%
geoDf = pd.read_csv('geospatialRegions')
import plotly.express as px
fig = px.scatter_geo(geoDf,lat='lat',lon='long', hover_name="Region", center=dict(lat=39.8283,lon=-98.5795))
fig.show()

# %%
#5 -> 1 Rule
listFiveOne =['Albuquerque NM', 'Atlanta GA', 'BatonRougeLA' , 'BemidjiMN' , 'Cartersville GA' , 'Charlotte NC', 'Chula Vista CA'
             'Cleveland OH','Columbus GA','Dallas TX','Denver CO','Encinitas CA','Louisville KY',
             'Manhattan NY','Mobile AL','Newark NJ','New Orleans LA','Oklahoma City OK', 'Salem VA'
             , 'Salt Lake City UT', 'San Diego CA' ,'Seattle WA','Shelby NC']

geoRuleFiveOne = pd.DataFrame(columns = ['Region', 'lat', 'long'])

for region in listFiveOne:
    geoRuleFiveOne =  geoRuleFiveOne.append(geoDf[geoDf.Region == region])

fig = px.scatter_geo(geoRuleFiveOne,lat='lat',lon='long', text="Region")
fig.show()

# %%
#Rule 3 -> 16

ruleThreeSixteen = ['Manhattan NY', 'Camden NJ', 'Charlotte NC', 'Charlottesville VA', 'Chicago IL', 'Cleveland OH', 'Cocoa Beach FL', 'Dallas TX', 'Detroit MI', 'Greensboro NC', 'Indianapolis IN', 'Kennewick WA', 'Kings Mountain NC', 'Lakeland FL', 'Minneapolis MN', 'Morgantown WV', 'Naples FL', 'Omaha NE', 'Phoenix AZ', 'Pittsburgh PA', 'Portland OR', 'Richland WA', 'Ridgewood NJ', 'San Antonio TX', 'Providence RI', 'San Diego CA', 'Seattle WA', 'Shelby NC', 'Tulsa OK', 'West Chester PA', 'White Plains NY', 'Wichita KS']

geoRuleThreeSixteen = pd.DataFrame(columns = ['Region', 'lat', 'long'])

for region in ruleThreeSixteen:
    geoRuleThreeSixteen =  geoRuleThreeSixteen.append(geoDf[geoDf.Region == region])

fig = px.scatter_geo(geoRuleThreeSixteen,lat='lat',lon='long', text="Region")
fig.update_layout(uniformtext_minsize=3, uniformtext_mode='hide')
fig.show()

# %%
ruleThreeSixteenHeat = ['Annapolis MD','Camden NJ','Charlotte NC','Chicago IL','Cleveland OH','Conroe TX','Coral Gables FL',
                        'Dallas TX','Detroit MI','Grand Rapids MI','Greensboro NC','Houston TX','Indianapolis IN','Iowa City IA',
                        'Kings Mountain NC','Melbourne FL','Mesa AZ','Minneapolis MN','Monroe NC','Morgantown WV','Mount Holly NJ',
                        'Naples FL','Newport RI','Phoenix AZ','Port Chester NY','Providence RI','Raleigh NC','Richland WA',
                        'Sacramento CA','San Antonio TX','Seattle WA','Spartanburg SC','Tulsa OK','West Chester PA','White Plains NY',
                        'Wichita KS']
mag = [0.1385,0.2805,0.5827,0.4581,0.4021,0.1963,0.5804,0.3943,0.1103,0.5417,0.2734,0.2305,0.3887,0.2964,0.7672,0.6945,0.4319,0.4440,
       0.5295, 0.4814,0.2278,0.1448,0.4747,0.0236,0.0210,0.5013,0.2688,0.4519,0.1617,0.6529,0.1022,0.5720,0.4985,0.5588,0.5237,0.2831]

geoRuleThreeSixteenHeat = pd.DataFrame(columns = ['Region', 'lat', 'long'])

for region in ruleThreeSixteenHeat:
    geoRuleThreeSixteenHeat =  geoRuleThreeSixteenHeat.append(geoDf[geoDf.Region == region])

geoRuleThreeSixteenHeat['Significance'] = mag
fig = px.density_mapbox(geoRuleThreeSixteenHeat,lat='lat',lon='long', z='Significance', radius=10,
                        center=dict(lat=39.8283,lon=-98.5795), zoom=3,mapbox_style="carto-positron",title='2006 Ampicillin/sulbactam -> Oxacillin',
                       height=700,width=1000,hover_name="Region")
fig.show()

# %%
geoRuleThreeSixteenHeat
# Out:
#                 Region        lat        long  Unnamed: 0
# 40        Annapolis MD  38.978640  -76.492786        40.0
# 67           Camden NJ  39.944840  -75.119891        67.0
# 58        Charlotte NC  35.227209  -80.843083        58.0
# 47          Chicago IL  41.875562  -87.624421        47.0
# 32        Cleveland OH  41.499656  -81.693681        32.0
# 83           Conroe TX  30.311877  -95.456051        83.0
# 59     Coral Gables FL  25.691543  -80.234549        59.0
# 34           Dallas TX  32.776272  -96.796856        34.0
# 17          Detroit MI  42.331551  -83.046640        17.0
# 44       Greensboro NC  36.072635  -79.791975        44.0
# 33          Houston TX  29.758938  -95.367697        33.0
# 147    Indianapolis IN  39.768333  -86.158350       147.0
# 148       Iowa City IA  41.661256  -91.529911       148.0
# 48   Kings Mountain NC  35.245061  -81.341052        48.0
# 26        Melbourne FL  28.106471  -80.637151        26.0
# ...

# %%
#Rule 7 17 -> 16

ruleSevenSeventeenSixteen2003 = ['Bangor ME', 'Bartlesville OK' , 'Bemidji MN', 'BirminghamAL2003',
                                'Charlotte NC','Charlottesville VA','ChulaVista CA','Cleveland OH',
                                'Coronado CA','Detroit MI','Euclid OH','Eugene OR','Fernandina Beach FL',
                                'Fort Lauderdale FL','Fort Pierce FL','Fountain Valley CA','Grand Forks ND',
                                'Hackensack NJ','Houston TX','Indianapolis IN','Iowa City IA','Jacksonville FL',
                                'La Jolla CA','Lakeland FL','La Mesa CA','Lexington KY','Long Beach CA','Louisville KY',
                                'Manhattan NY','Mayfield Heights OH','Melbourne FL','Mesa AZ','Miami FL','Miami Beach FL',
                                'Mobile AL','Monroe NC','Morgantown WV','Munster IN','Naples FL','Newark NJ',
                                'Newberg OR','Okeechobee FL','Oklahoma City OK','Pembroke Pines FL','Phoenix AZ',
                                'Plantation FL','Portland OR','Ridgewood NJ','Rochester NY','Sacramento CA','San Diego CA',
                                 'San Francisco CA','Sioux Falls SD','Spartanburg SC','Stanford CA','Tulsa OK',
                                 'Vinita OK','Washington DC','West Palm Beach FL','White Plains NY','Wichita KS','Albuquerque NM',
                                'Annapolis MD', 'Atlantis FL']

geoSevenSeventeenSixteen2003 = pd.DataFrame(columns = ['Region', 'lat', 'long'])

for region in ruleSevenSeventeenSixteen2003:
    geoSevenSeventeenSixteen2003 =  geoSevenSeventeenSixteen2003.append(geoDf[geoDf.Region == region])

fig = px.scatter_geo(geoSevenSeventeenSixteen2003,lat='lat',lon='long', hover_name="Region", title="2003 Rule 7 17 -> 16")
fig.update_layout(uniformtext_minsize=3, uniformtext_mode='hide')
fig.show()

# %%
#Rule 7 17 -> 4

ruleSevenSeventeenFour2004 = ['Albuquerque NM', 'Annapolis MD', 'Atlanta GA','Atlantis FL','Bangor ME','Bartlesville OK','Bemidji MN',
                              'Birmingham AL','Burlington MA','Charlottesville VA','Chula Vista CA','Cleveland OH','Cocoa Beach FL',
                              'Coronado CA','Danville PA','Decatur GA','Detroit MI','Encinitas CA','Euclid OH','Eugene OR',
                              'Fernandina Beach FL','Houston TX','Indianapolis IN','Jacksonville FL','Kennewick WA','La Jolla CA',
                              'Lakeland FL','La Mesa CA','Lexington KY','Long Beach CA','Louisville KY','Mayfield Heights OH','Melbourne FL',
                              'Miami Beach FL','Minneapolis MN','Monroe NC','Morgantown WV','Naples FL','Newark NJ','Philadelphia PA',
                              'Phoenix AZ','Richland WA','Ridgewood NJ','Rochester NY','Sacramento CA','Salem VA','Salt Lake City UT','San Diego CA',
                              'Shelby NC','Sioux Falls SD','Sodus NY','Spartanburg SC','St. Louis MO','Tulsa OK','Vinita OK','West Palm Beach FL',
                              'White Plains NY','Wichita KS']

geoSevenSeventeenFour2004 = pd.DataFrame(columns = ['Region', 'lat', 'long'])

for region in ruleSevenSeventeenFour2004:
    geoSevenSeventeenFour2004 =  geoSevenSeventeenFour2004.append(geoDf[geoDf.Region == region])

fig = px.scatter_geo(geoSevenSeventeenFour2004,lat='lat',lon='long', hover_name="Region", title="2004 Rule 7 17 -> 4")
fig.update_layout(uniformtext_minsize=3, uniformtext_mode='hide')
fig.show()

# %%
len(geoRuleFiveOne)
# Out:
# 5

# %%
years = ["1999" , "2000" , "2001" , "2002" , "2003" , "2004" , "2005" , "2006" , "2007" , "2008" , "2009" , "2010" , "2011" , "2012"]

def plotCountByRegion(region):
    if "/" in region:
        region = region.replace("/", "")
    
    count = []
    
    for year in range(1999,2013):
        
        fileName = "temp2/{}{}.csv".format(region.replace(" ",""), year)
        try:
            df = pd.read_csv(fileName)
            l = len(df.index)
            count.append(l)
        except OSError as e:
            count.append(0)
            
    plt.bar(years, count)
    plt.xticks(rotation=90)
    plt.ylabel("Number of antibiogram tests")
    plt.xlabel("Year")
    plt.title(region)
    plt.savefig( 'plots/{}.png'.format(region.replace(" ","")) , facecolor='white', edgecolor='white')
    plt.show()

# %%
from math import radians, cos, sin, asin, sqrt
def distance(lat1, lat2, lon1, lon2):
    lon1 = radians(lon1)
    lon2 = radians(lon2)
    lat1 = radians(lat1)
    lat2 = radians(lat2)
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
    c = 2 * asin(sqrt(a))
    r = 6371
    return(c * r)

# %%
def distanceBetween(place1, place2):
    p1 = geoDf.loc[geoDf['Region'] == place1]
    p2 = geoDf.loc[geoDf['Region'] == place2]
    lon1 = p1.long
    lon2 = p2.long
    lat1 = p1.lat
    lat2 = p2.lat
    d = distance(lat1, lat2, lon1, lon2)
    return(d)
    
distanceBetween('Manhattan NY','Newark NJ')
# Out:
# 18.87410882503023

# %%
for region1 in regionList:
    for region2 in regionList:
        if(region1 == region2):
            continue
        if(distanceBetween(region1,region2) < 1000):
            #nx.add_path(G, [region1,region2])
            G.add_edge(region1,region2)

# %%
distanceBetween('San Antonio TX','Las Vegas NV')
# Out:
#    Unnamed: 0          Region      lat       long
# 0           0  San Antonio TX  29.4246 -98.495141
#     Unnamed: 0        Region        lat        long
# 14          14  Las Vegas NV  36.167256 -115.148516
# 1724.4798100839917

# %%
plotCountByRegion('MilfordMI')

# %%
plotCountByRegion('AlbuquerqueNM')

# %%
#(e.g, cities with 0 records, 0-100 records, 100-500 records, 500-1000 records, 1000-2000, and >=2000)

categories = ["0" , "0 - 100" , "100 - 500" , "500 - 1000" , "1000 - 2000" , ">= 2000"]

def plotCountByRegionAggr(year):
    
    count = [0 , 0 , 0 , 0 , 0 , 0]
    
    for region in regionList:
        
        fileName = "temp2/{}{}.csv".format(region.replace(" ",""), year)
        try:
            df = pd.read_csv(fileName)
            l = len(df.index)
            if(l == 0):
                count[0] = count[0] + 1
            if(l > 0 and l < 100):
                count[1] = count[1] + 1
            if(l >= 100 and l < 500):
                count[2] = count[2] + 1
            if(l >= 500 and l < 1000):
                count[3] = count[3] + 1
            if(l >= 1000 and l < 2000):
                count[4] = count[4] + 1
            if(l >= 2000):
                count[5] = count[5] + 1
            
        except OSError as e:
            count[0] = count[0] + 1
            
    plt.bar(categories, count)
    plt.xticks(rotation=45)
    plt.ylabel("Number of Cities")
    plt.xlabel("Number of Antibiogram Records")
    plt.title(year)
    plt.savefig('plotsAggr/Year{}.png'.format(year), facecolor='white', edgecolor='white')
    plt.show

# %%
plotCountByRegionAggr(2012)

# %%
ruleNineSeventeenSixteenHeat = ['Albuquerque NM','Annapolis MD','Atlantis FL','Bangor ME','Bartlesville OK','Bemidji MN','Biloxi MS','Birmingham AL','Boulder City NV','Camden NJ','Charlottesville VA','Chicago IL','Chula Vista CA','Cleveland OH','Coronado CA','Cottage Grove OR','Dallas TX','Decatur GA',
                                'Detroit MI','Euclid OH','Eugene OR','Federal Way WA','Fernandina Beach FL','Fort Lauderdale FL','Fort Pierce FL','Fountain Valley CA','Grand Forks ND','Greensboro NC','Hackensack NJ','Honolulu HI','Houston TX','Indianapolis IN','Iowa City IA','Jacksonville FL','Ketchikan AK',
                                'Knoxville TN','La Jolla CA','Lakeland FL','LaMesa CA','Lexington KY','Long Beach CA','Los Angeles CA','Louisville KY','Madison WI','Manhattan NY','Mayfield Heights OH','Memphis TN','Mesa AZ',
                                'Miami Beach FL','Miami FL','Mobile AL','Monroe NC','Mount Holly NJ','Munster IN','Naples FL','Newberg OR','Oklahoma City OK','Omaha NE','Pembroke Pines FL','Phoenix AZ','Pittsburgh PA','Portland OR',
                                'Raleigh NC','Reading PA','Ridgewood NJ','Rochester NY','Sacramento CA','San Diego CA','San Francisco CA','Santa Monica CA','Shreveport LA','Sioux Falls SD','Spartanburg SC','Springfield IL','Stanford CA',
                                'St. Louis MO','Tacoma WA','Tulsa OK','Washington DC','West Palm Beach FL','Wichita KS','Wilmington DE','','','']
mag = [0.3276,0.4738,0.5403,0.3184,0.2466,0.2722,0.0593,0.3358,0.5158,0.5294,0.4629,0.4364,0.4421,0.4352,0.4837,0.2292,0.6446,
       0.4501,0.4683,0.5923,0.4627,0.5077,0.4016,0.6234,0.5643,0.6189,0.1726,0.4293,0.4966,0.3244,0.5713,0.3780,0.2366,0.5361,0.3122,
       0.4038,0.3255,0.4990,0.4634,0.3584,0.4156,0.5588,0.5814,0.2555,0.3565,0.4271,0.5552,0.4855,0.6027,0.6521,0.5413,0.4611,0.4702,
       0.1745,0.3670,0.3650,0.4417,0.3391,0.5761,0.5204,0.5151,0.4319,0.4068,0.3490,0.4716,0.4203,0.3616,0.4204,0.3653,0.4587,0.5509,
       0.4080,0.4299,0.4177,0.2433,0.4964,0.4345,0.3875,0.2374,0.4290,0.5005,0.5313]

geoRuleNineSeventeenSixteenHeat = pd.DataFrame(columns = ['Region', 'lat', 'long'])

for region in ruleNineSeventeenSixteenHeat:
    geoRuleNineSeventeenSixteenHeat =  geoRuleNineSeventeenSixteenHeat.append(geoDf[geoDf.Region == region])

geoRuleNineSeventeenSixteenHeat['Prominence'] = mag

fig = px.density_mapbox(geoRuleNineSeventeenSixteenHeat,lat='lat',lon='long', z='Prominence', radius=10,
                        center=dict(lat=39.8283,lon=-98.5795), zoom=3,mapbox_style="carto-positron",title='2003 Erythromycin & Penicillin -> Oxacillin',
                       height=700,width=1000,hover_name="Region")
fig.show()
